# %% [markdown]
# # Grape variety classification based on wine description
#
# Este exemplo utiliza diferentes técnicas que podem ser utilizadas em projetos de machine learning.
#
# https://www.kaggle.com/code/atrigo/classification-with-nlp-xgboost-and-pipelines
